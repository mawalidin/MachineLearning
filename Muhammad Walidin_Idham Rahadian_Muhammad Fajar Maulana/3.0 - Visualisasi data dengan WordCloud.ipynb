# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from wordcloud import WordCloud

# %%
mpl.rcParams['font.size']=14

# %%
raw = pd.read_csv( "data/data/1.2_data_review_cleaner_pure.csv")
raw['review'] = raw['review'].apply(lambda x: x.replace(","," "))

# %%
wordcloud = WordCloud(
                         background_color='white',
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(raw['review']))

# %%
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("data/image/word_cloud.png", dpi=1000)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000001D4CFBACEE0>
