# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_csv('data/datat.csv')
df = pd.read_excel('data/labeled6.xlsx')

# %%
#Menampilkan informasi dari jumlah kolom dan baris, serta lima sampel teratas dari dataframe df_items
print('shape : {}'.format(df.shape))
df.head()
# Out:
# shape : (800, 7)
#                          Nama dan Tanggal                 Nama        Tanggal  \
# 0  Hendy Ucok Manurung\n22 April 2021\n\t  Hendy Ucok Manurung  22 April 2021
# 1       Ratna Djauhari\n23 April 2021\n\t       Ratna Djauhari  23 April 2021
# 2         Karina Ismir\n22 April 2021\n\t         Karina Ismir  22 April 2021
# 3             Sudi Ono\n23 April 2021\n\t             Sudi Ono  23 April 2021
# 4         Tetep Herman\n21 April 2021\n\t         Tetep Herman  21 April 2021
#
#    Rating                                             Review Aspect Category  \
# 0       3  Sangat Membantu. Terutama di kondisi Pandemi. ...       Pelayanan
# 1       5  Baru pertama konsultasi dokter lewat halo doc ...       Pelayanan
# 2       1  astaga obatnya semakin lama beli obat di halo ...           Harga
# 3       5  Terimakasih Halodoc atas pelayanannya sangat b...       Pelayanan
# 4       1  Ada yang nelpon ke no saya katanya dari halodo...          Sistem
#
#   Polarity
# 0  Negatif
# 1  Negatif
# 2  Negatif
# 3  Positif
# 4  Positif

# %%
#Mengeliminasi kolom tidak guna
raw = df.drop(columns=['Nama dan Tanggal', 'Nama', 'Tanggal'])
raw.head(100)
# Out:
#     Rating                                             Review  \
# 0        3  Sangat Membantu. Terutama di kondisi Pandemi. ...
# 1        5  Baru pertama konsultasi dokter lewat halo doc ...
# 2        1  astaga obatnya semakin lama beli obat di halo ...
# 3        5  Terimakasih Halodoc atas pelayanannya sangat b...
# 4        1  Ada yang nelpon ke no saya katanya dari halodo...
# ..     ...                                                ...
# 95       5  Aplikasi ini membuat dokter spt keluarga, saha...
# 96       1  Gimana sih ini. Masa dokter nya yg ngelewatin ...
# 97       2  Kemaren tepatnya hari kamis tgl 04-maret-2021 ...
# 98       5  Sangat membant untuk konsultasi dari rumah saj...
# 99       1  Parah vaksin lansia dosis ke 2 disini, parah b...
#
#       Aspect Category Polarity
# 0           Pelayanan  Negatif
# 1           Pelayanan  Negatif
# 2               Harga  Negatif
# 3           Pelayanan  Positif
# 4              Sistem  Positif
# ..                ...      ...
# 95  Anekdot/Serbaneka  Positif
# 96          Pelayanan  Negatif
# 97  Anekdot/Serbaneka  Negatif
# 98          Pelayanan  Positif
# 99          Pelayanan  Positif
#
# [100 rows x 4 columns]

# %%
print('Jumlah NaN value pada Review : ', len(raw[raw.Review.isna() == True]))

#Mengganti nilai NaN
#raw.Description.fillna('Tanpa Review', inplace = True)
#print('Jumlah NaN value pada Description : ', len(raw[raw.Description.isna() == True]))
# Out:
# Jumlah NaN value pada Review :  0

# %%
raw
# Out:
#      Rating                                             Review  \
# 0         3  Sangat Membantu. Terutama di kondisi Pandemi. ...
# 1         5  Baru pertama konsultasi dokter lewat halo doc ...
# 2         1  astaga obatnya semakin lama beli obat di halo ...
# 3         5  Terimakasih Halodoc atas pelayanannya sangat b...
# 4         1  Ada yang nelpon ke no saya katanya dari halodo...
# ..      ...                                                ...
# 795       5       Semudah diklik, praktis dan sangat membantu👌
# 796       5        Pelayanannya ramah . Paham dengan bidangnya
# 797       4  bagus aplikasi nya terasa punya dokter pribadi...
# 798       5    sangat memudahkan konsultasi tanpa keluar rumah
# 799       5     Sangat membantu dan pelayanan dokter memuaskan
#
#        Aspect Category Polarity
# 0            Pelayanan  Negatif
# 1            Pelayanan  Negatif
# 2                Harga  Negatif
# 3            Pelayanan  Positif
# 4               Sistem  Positif
# ..                 ...      ...
# 795  Anekdot/Serbaneka  Positif
# 796  Anekdot/Serbaneka  Positif
# 797  Anekdot/Serbaneka  Positif
# 798          Pelayanan  Positif
# 799          Pelayanan  Positif
#
# [800 rows x 4 columns]

# %%
raw = raw.rename(columns={'Rating':'rating','Review':'review','Aspect Category':'aspect_category','Polarity':'polarity'})
raw
# Out:
#      rating                                             review  \
# 0         3  Sangat Membantu. Terutama di kondisi Pandemi. ...
# 1         5  Baru pertama konsultasi dokter lewat halo doc ...
# 2         1  astaga obatnya semakin lama beli obat di halo ...
# 3         5  Terimakasih Halodoc atas pelayanannya sangat b...
# 4         1  Ada yang nelpon ke no saya katanya dari halodo...
# ..      ...                                                ...
# 795       5       Semudah diklik, praktis dan sangat membantu👌
# 796       5        Pelayanannya ramah . Paham dengan bidangnya
# 797       4  bagus aplikasi nya terasa punya dokter pribadi...
# 798       5    sangat memudahkan konsultasi tanpa keluar rumah
# 799       5     Sangat membantu dan pelayanan dokter memuaskan
#
#        aspect_category polarity
# 0            Pelayanan  Negatif
# 1            Pelayanan  Negatif
# 2                Harga  Negatif
# 3            Pelayanan  Positif
# 4               Sistem  Positif
# ..                 ...      ...
# 795  Anekdot/Serbaneka  Positif
# 796  Anekdot/Serbaneka  Positif
# 797  Anekdot/Serbaneka  Positif
# 798          Pelayanan  Positif
# 799          Pelayanan  Positif
#
# [800 rows x 4 columns]

# %%
raw.to_csv('data/data/data_raw.csv', index=False)
