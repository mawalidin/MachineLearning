# %% [markdown]
# By: 10117094	Muhammad Walidin
#     10116476	Idham Rahadian
#     10116490	Muhammad Fajar Maulana

# %%
import pandas as pd
import numpy as np
import string
import re
from collections import Counter

# %%
raw = pd.read_csv( "data/data/1.2_data_review_cleaner_pure.csv")

# %%
print(raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rating      804 non-null    int64
#  1   review      804 non-null    object
#  2   avg_word    804 non-null    float64
#  3   word_count  804 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 25.2+ KB
# None

# %%
raw.head()
# Out:
#    rating                                             review  avg_word  \
# 0       5                             'tidak','ada','ulasan'  6.666667
# 1       5                    'puas','kecil','tapi','kencang'  7.000000
# 2       1  'barang','yang','datang','bukan','baracuda','t...  6.428571
# 3       5  'terima,kasih','barang','sudah','sampai','seha...  7.666667
# 4       5  'barang','bagus','pengirman','cepat','mantap',...  7.666667
#
#    word_count
# 0           3
# 1           4
# 2          13
# 3          17
# 4           6

# %%
raw['review'] = raw['review'].apply(lambda x: x.replace(","," "))
raw
# Out:
#      rating                                             review  avg_word  \
# 0         5                             'tidak' 'ada' 'ulasan'  6.666667
# 1         5                    'puas' 'kecil' 'tapi' 'kencang'  7.000000
# 2         1  'barang' 'yang' 'datang' 'bukan' 'baracuda' 't...  6.428571
# 3         5  'terima kasih' 'barang' 'sudah' 'sampai' 'seha...  7.666667
# 4         5  'barang' 'bagus' 'pengirman' 'cepat' 'mantap' ...  7.666667
# ..      ...                                                ...       ...
# 799       5  'barang' 'kondisi' 'oke' 'respon' 'cepat' 'dan...  7.000000
# 800       5  'barang' 'sampai' 'tepat' 'waktu' 'sesuai' 'ta...  7.318182
# 801       5  'pelayanan' 'sangat' 'bagus' 'barang' 'sesuai'...  7.700000
# 802       5  'barang' 'sampai' 'lebih' 'cepat' 'dan' 'dalam...  6.888889
# 803       3                     'bonus' 'bohong' 'tidak' 'ada'  6.750000
#
#      word_count
# 0             3
# 1             4
# 2            13
# 3            17
# 4             6
# ..          ...
# 799           8
# 800          22
# 801          20
# 802          18
# 803           4
#
# [804 rows x 4 columns]

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()
raw['review'] = raw['review'].apply(lambda x: stemmer.stem(x).replace(" ",","))
raw
# Out:
#      rating                                             review  avg_word  \
# 0         5                                     tidak,ada,ulas  6.666667
# 1         5                            puas,kecil,tapi,kencang  7.000000
# 2         1  barang,yang,datang,bukan,baracuda,tiga,lima,tu...  6.428571
# 3         5  terima,kasih,barang,sudah,sampai,hari,langsung...  7.666667
# 4         5            barang,bagus,pengirman,cepat,mantap,deh  7.666667
# ..      ...                                                ...       ...
# 799       5    barang,kondisi,oke,respon,cepat,dan,sangat,baik  7.000000
# 800       5  barang,sampai,tepat,waktu,sesuai,target,lazada...  7.318182
# 801       5  layan,sangat,bagus,barang,sesuai,dengan,yang,p...  7.700000
# 802       5  barang,sampai,lebih,cepat,dan,dalam,kondisi,sa...  6.888889
# 803       3                             bonus,bohong,tidak,ada  6.750000
#
#      word_count
# 0             3
# 1             4
# 2            13
# 3            17
# 4             6
# ..          ...
# 799           8
# 800          22
# 801          20
# 802          18
# 803           4
#
# [804 rows x 4 columns]

# %%
def avg_word(words):
  return (sum(len(word) for word in words)/len(words))

raw['avg_word'] = raw['review'].apply(lambda x: avg_word(x.split(",")))

# %%
raw.head()
# Out:
#    rating                                             review  avg_word  \
# 0       5                                     tidak,ada,ulas  4.000000
# 1       5                            puas,kecil,tapi,kencang  5.000000
# 2       1  barang,yang,datang,bukan,baracuda,tiga,lima,tu...  4.923077
# 3       5  terima,kasih,barang,sudah,sampai,hari,langsung...  5.444444
# 4       5            barang,bagus,pengirman,cepat,mantap,deh  5.666667
#
#    word_count
# 0           3
# 1           4
# 2          13
# 3          17
# 4           6

# %%
raw.to_csv("data/data/1.3_data_review_stemmed.csv", index=False)
